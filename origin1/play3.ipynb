# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import networkx as nx
import matplotlib.pyplot as plt

G = nx.Graph()
G.add_edge('A', 'B', weight=13, relation='friend')
G.add_edge('B', 'C', weight=9, relation='family')
G.add_edge('B', 'D', weight=7, relation='friend')
G.edges(data=True)
# Out:
# EdgeDataView([('A', 'B', {'weight': 13, 'relation': 'friend'}), ('B', 'C', {'weight': 9, 'relation': 'family'}), ('B', 'D', {'weight': 7, 'relation': 'friend'})])

# %%
G.add_node('A', role="Trader")
G.add_node('B', role="Analyst")
G.nodes(data=True)
# Out:
# NodeDataView({'A': {'role': 'Trader'}, 'B': {'role': 'Analyst'}, 'C': {}, 'D': {}})

# %%
from IPython.display import display
nx.draw_networkx(G, with_labels=True)

# %%
from networkx.algorithms import bipartite
B = nx.Graph()
B.add_nodes_from(['A', 'B', 'C'], bipartite=0)
B.add_nodes_from([1, 2, 3], bipartite=1)
G.add_edges_from([('A', 1), ('B', 1), ('C', 3)])
bipartite.is_bipartite(B)
nx.draw_networkx(G)
